# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add to the list of cities
    if city not in cities:
        cities.append(city)
# Print the city count to determine sufficient count
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | victor harbor
# Processing Record 2 of Set 1 | las varas
# Processing Record 3 of Set 1 | ranong
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | vardo
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | yarkovo
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | sovetskiy
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | ketchikan
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | canutama
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | roma
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | ayaviri
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | havelock
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | zhigansk
# Processing Record 38 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 1 | kavaratti
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | puerto del rosario
# Processing Record 47 of Set 1 | ola
# Processing Record 48 of Set 1 | synya
# Processing Record 49 of Set 1 | erie
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | nome
# Processing Record 2 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 3 of Set 2 | peniche
# Processing Record 4 of Set 2 | makakilo city
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | flin flon
# Processing Record 7 of Set 2 | muromtsevo
# Processing Record 8 of Set 2 | coquimbo
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | calafell
# Processing Record 15 of Set 2 | kungurtug
# Processing Record 16 of Set 2 | yulara
# Processing Record 17 of Set 2 | youkounkoun
# Processing Record 18 of Set 2 | vysokogornyy
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | chateauroux
# Processing Record 22 of Set 2 | vinh
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | baft
# Processing Record 26 of Set 2 | haimen
# Processing Record 27 of Set 2 | bosaso
# Processing Record 28 of Set 2 | carballo
# Processing Record 29 of Set 2 | kuala terengganu
# Processing Record 30 of Set 2 | cape canaveral
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | bonthe
# Processing Record 34 of Set 2 | mildura
# Processing Record 35 of Set 2 | burnie
# Processing Record 36 of Set 2 | champerico
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | lorengau
# Processing Record 40 of Set 2 | taoudenni
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | bom jesus
# Processing Record 43 of Set 2 | roebourne
# Processing Record 44 of Set 2 | santa cruz
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | mogadouro
# Processing Record 50 of Set 2 | deputatskiy
# Processing Record 1 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | alta gracia
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | westport
# Processing Record 10 of Set 3 | nerchinskiy zavod
# Processing Record 11 of Set 3 | kamaishi
# Processing Record 12 of Set 3 | havoysund
# Processing Record 13 of Set 3 | puri
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | grand gaube
# Processing Record 16 of Set 3 | hualmay
# Processing Record 17 of Set 3 | warri
# Processing Record 18 of Set 3 | beringovskiy
# Processing Record 19 of Set 3 | necochea
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | dunedin
# Processing Record 22 of Set 3 | bilimora
# Processing Record 23 of Set 3 | mazatlan
# Processing Record 24 of Set 3 | hohhot
# Processing Record 25 of Set 3 | marevo
# Processing Record 26 of Set 3 | rocha
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | zeya
# Processing Record 30 of Set 3 | rafraf
# Processing Record 31 of Set 3 | lundazi
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | los llanos de aridane
# Processing Record 34 of Set 3 | chunskiy
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | zhaodong
# Processing Record 37 of Set 3 | grindavik
# Processing Record 38 of Set 3 | waipawa
# Processing Record 39 of Set 3 | lazaro cardenas
# Processing Record 40 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 3 | hay river
# Processing Record 42 of Set 3 | potam
# Processing Record 43 of Set 3 | keffi
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | ilhabela
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | poitiers
# Processing Record 48 of Set 3 | fershampenuaz
# Processing Record 49 of Set 3 | narsaq
# Processing Record 50 of Set 3 | olinda
# Processing Record 1 of Set 4 | namwala
# Processing Record 2 of Set 4 | dali
# Processing Record 3 of Set 4 | jinchang
# Processing Record 4 of Set 4 | guelengdeng
# City not found. Skipping...
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | cap malheureux
# Processing Record 8 of Set 4 | dire dawa
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | kudahuvadhoo
# Processing Record 11 of Set 4 | ushuaia
# Processing Record 12 of Set 4 | saskylakh
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | kibre mengist
# Processing Record 16 of Set 4 | hovd
# Processing Record 17 of Set 4 | cayenne
# Processing Record 18 of Set 4 | cairns
# Processing Record 19 of Set 4 | banyuwangi
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | morondava
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | sangar
# Processing Record 24 of Set 4 | walvis bay
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | hanyang
# Processing Record 27 of Set 4 | dzaoudzi
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | mehamn
# Processing Record 30 of Set 4 | nemuro
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | mangrol
# Processing Record 33 of Set 4 | opuwo
# Processing Record 34 of Set 4 | port lincoln
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | moscow
# Processing Record 37 of Set 4 | reconquista
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | boa vista
# Processing Record 40 of Set 4 | lerici
# Processing Record 41 of Set 4 | moreira sales
# Processing Record 42 of Set 4 | ambon
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | hilo
# Processing Record 46 of Set 4 | osakarovka
# Processing Record 47 of Set 4 | codrington
# Processing Record 48 of Set 4 | raga
# Processing Record 49 of Set 4 | presidencia roque saenz pena
# Processing Record 50 of Set 4 | te anau
# Processing Record 1 of Set 5 | vestmannaeyjar
# Processing Record 2 of Set 5 | shingu
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | shache
# Processing Record 5 of Set 5 | caldwell
# Processing Record 6 of Set 5 | hobart
# Processing Record 7 of Set 5 | kongolo
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | teguise
# Processing Record 10 of Set 5 | zlobin
# Processing Record 11 of Set 5 | emerald
# Processing Record 12 of Set 5 | sambava
# Processing Record 13 of Set 5 | new norfolk
# Processing Record 14 of Set 5 | tasiilaq
# Processing Record 15 of Set 5 | koutsouras
# Processing Record 16 of Set 5 | maceio
# Processing Record 17 of Set 5 | oda
# Processing Record 18 of Set 5 | kapit
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | rincon de la victoria
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | marzuq
# Processing Record 23 of Set 5 | cervo
# Processing Record 24 of Set 5 | borgomanero
# Processing Record 25 of Set 5 | honiara
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | la ronge
# Processing Record 28 of Set 5 | shenjiamen
# Processing Record 29 of Set 5 | dalbandin
# Processing Record 30 of Set 5 | zlitan
# Processing Record 31 of Set 5 | kanniyakumari
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | lasa
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | camabatela
# Processing Record 36 of Set 5 | antalaha
# Processing Record 37 of Set 5 | hofn
# Processing Record 38 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 5 | cibitoke
# Processing Record 40 of Set 5 | cap-aux-meules
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | sisimiut
# Processing Record 43 of Set 5 | newcastle
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | westlock
# Processing Record 46 of Set 5 | langham
# Processing Record 47 of Set 5 | otradnoye
# Processing Record 48 of Set 5 | puerto ayora
# Processing Record 49 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 5 | soure
# Processing Record 1 of Set 6 | caxito
# Processing Record 2 of Set 6 | manassas park
# Processing Record 3 of Set 6 | saint anthony
# Processing Record 4 of Set 6 | lasem
# Processing Record 5 of Set 6 | santa fe
# Processing Record 6 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 6 | tessalit
# Processing Record 8 of Set 6 | junnar
# Processing Record 9 of Set 6 | esso
# Processing Record 10 of Set 6 | upernavik
# Processing Record 11 of Set 6 | northam
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | copiapo
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | gat
# Processing Record 16 of Set 6 | kodiak
# Processing Record 17 of Set 6 | kaniama
# Processing Record 18 of Set 6 | strezhevoy
# Processing Record 19 of Set 6 | port elizabeth
# Processing Record 20 of Set 6 | fortuna
# Processing Record 21 of Set 6 | sosnogorsk
# Processing Record 22 of Set 6 | northborough
# Processing Record 23 of Set 6 | iberia
# Processing Record 24 of Set 6 | kiunga
# Processing Record 25 of Set 6 | avarua
# Processing Record 26 of Set 6 | verkhnyaya sinyachikha
# Processing Record 27 of Set 6 | port-gentil
# Processing Record 28 of Set 6 | nalut
# Processing Record 29 of Set 6 | carnarvon
# Processing Record 30 of Set 6 | gallup
# Processing Record 31 of Set 6 | port-cartier
# Processing Record 32 of Set 6 | imperia
# Processing Record 33 of Set 6 | chernyshevskiy
# Processing Record 34 of Set 6 | orlik
# Processing Record 35 of Set 6 | sur
# Processing Record 36 of Set 6 | bairiki
# Processing Record 37 of Set 6 | san antonio
# Processing Record 38 of Set 6 | aranos
# Processing Record 39 of Set 6 | poum
# Processing Record 40 of Set 6 | sabang
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 6 | nipawin
# Processing Record 44 of Set 6 | aktash
# Processing Record 45 of Set 6 | acapulco
# Processing Record 46 of Set 6 | kidal
# Processing Record 47 of Set 6 | ishigaki
# Processing Record 48 of Set 6 | lagos
# Processing Record 49 of Set 6 | portland
# Processing Record 50 of Set 6 | korla
# Processing Record 1 of Set 7 | plettenberg bay
# Processing Record 2 of Set 7 | padang
# Processing Record 3 of Set 7 | pouebo
# Processing Record 4 of Set 7 | neuquen
# Processing Record 5 of Set 7 | chapais
# Processing Record 6 of Set 7 | aden
# Processing Record 7 of Set 7 | rafai
# Processing Record 8 of Set 7 | parkersburg
# Processing Record 9 of Set 7 | tromso
# Processing Record 10 of Set 7 | sun valley
# Processing Record 11 of Set 7 | viedma
# Processing Record 12 of Set 7 | matay
# Processing Record 13 of Set 7 | kandrian
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | kaura namoda
# Processing Record 16 of Set 7 | nhamunda
# Processing Record 17 of Set 7 | lata
# Processing Record 18 of Set 7 | okha
# Processing Record 19 of Set 7 | richards bay
# Processing Record 20 of Set 7 | san luis
# Processing Record 21 of Set 7 | quatre cocos
# Processing Record 22 of Set 7 | hirara
# Processing Record 23 of Set 7 | mayo
# Processing Record 24 of Set 7 | bilibino
# Processing Record 25 of Set 7 | guadalupe y calvo
# Processing Record 26 of Set 7 | iralaya
# Processing Record 27 of Set 7 | margate
# Processing Record 28 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 7 | general roca
# Processing Record 30 of Set 7 | svirstroy
# Processing Record 31 of Set 7 | ahmadnagar
# Processing Record 32 of Set 7 | sept-iles
# Processing Record 33 of Set 7 | hobyo
# Processing Record 34 of Set 7 | tilichiki
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | itacoatiara
# Processing Record 37 of Set 7 | victoria
# Processing Record 38 of Set 7 | rey bouba
# Processing Record 39 of Set 7 | yuksekova
# Processing Record 40 of Set 7 | ballina
# Processing Record 41 of Set 7 | kailua
# Processing Record 42 of Set 7 | tinsukia
# Processing Record 43 of Set 7 | khasan
# Processing Record 44 of Set 7 | najran
# Processing Record 45 of Set 7 | boguchany
# Processing Record 46 of Set 7 | ngunguru
# Processing Record 47 of Set 7 | conceicao do araguaia
# Processing Record 48 of Set 7 | mangan
# Processing Record 49 of Set 7 | srandakan
# Processing Record 50 of Set 7 | isetskoye
# Processing Record 1 of Set 8 | limanowa
# Processing Record 2 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 8 | rio grande
# Processing Record 4 of Set 8 | san patricio
# Processing Record 5 of Set 8 | juegang
# Processing Record 6 of Set 8 | bandarbeyla
# Processing Record 7 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 8 of Set 8 | catuday
# Processing Record 9 of Set 8 | aklavik
# Processing Record 10 of Set 8 | terrace bay
# Processing Record 11 of Set 8 | la macarena
# Processing Record 12 of Set 8 | tezu
# Processing Record 13 of Set 8 | saint-augustin
# Processing Record 14 of Set 8 | inhambane
# Processing Record 15 of Set 8 | marsa matruh
# Processing Record 16 of Set 8 | chokurdakh
# Processing Record 17 of Set 8 | takab
# Processing Record 18 of Set 8 | conde
# Processing Record 19 of Set 8 | banjar
# Processing Record 20 of Set 8 | skiros
# City not found. Skipping...
# Processing Record 21 of Set 8 | alacranes
# Processing Record 22 of Set 8 | hua hin
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | flinders
# Processing Record 25 of Set 8 | arlit
# Processing Record 26 of Set 8 | anchorage
# Processing Record 27 of Set 8 | omboue
# Processing Record 28 of Set 8 | constitucion
# Processing Record 29 of Set 8 | elesbao veloso
# Processing Record 30 of Set 8 | yeniseysk
# Processing Record 31 of Set 8 | east london
# Processing Record 32 of Set 8 | bambous virieux
# Processing Record 33 of Set 8 | brae
# Processing Record 34 of Set 8 | tadine
# Processing Record 35 of Set 8 | makubetsu
# Processing Record 36 of Set 8 | camargo
# Processing Record 37 of Set 8 | mpongwe
# Processing Record 38 of Set 8 | sosva
# Processing Record 39 of Set 8 | juba
# Processing Record 40 of Set 8 | souillac
# Processing Record 41 of Set 8 | enkhuizen
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | kemise
# Processing Record 44 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 8 | tingo maria
# Processing Record 46 of Set 8 | mogadishu
# Processing Record 47 of Set 8 | yichang
# Processing Record 48 of Set 8 | labuhan
# Processing Record 49 of Set 8 | praia
# Processing Record 50 of Set 8 | chalmette
# Processing Record 1 of Set 9 | dharangaon
# Processing Record 2 of Set 9 | bilma
# Processing Record 3 of Set 9 | kalmunai
# Processing Record 4 of Set 9 | georgetown
# Processing Record 5 of Set 9 | bethlehem
# Processing Record 6 of Set 9 | novyy urengoy
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | nicoya
# Processing Record 9 of Set 9 | koutiala
# Processing Record 10 of Set 9 | zhob
# Processing Record 11 of Set 9 | tvedestrand
# Processing Record 12 of Set 9 | leningradskiy
# Processing Record 13 of Set 9 | kupang
# Processing Record 14 of Set 9 | nizhniy kuranakh
# Processing Record 15 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 16 of Set 9 | sibolga
# Processing Record 17 of Set 9 | goderich
# Processing Record 18 of Set 9 | dingzhou
# Processing Record 19 of Set 9 | itarema
# Processing Record 20 of Set 9 | esmeralda
# Processing Record 21 of Set 9 | ulladulla
# Processing Record 22 of Set 9 | tacuarembo
# Processing Record 23 of Set 9 | ust-tsilma
# Processing Record 24 of Set 9 | nizwa
# Processing Record 25 of Set 9 | bull savanna
# Processing Record 26 of Set 9 | faanui
# Processing Record 27 of Set 9 | puerto el triunfo
# Processing Record 28 of Set 9 | hamilton
# Processing Record 29 of Set 9 | fare
# Processing Record 30 of Set 9 | parrita
# Processing Record 31 of Set 9 | trelleborg
# Processing Record 32 of Set 9 | wakefield
# Processing Record 33 of Set 9 | batsfjord
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | rio gallegos
# Processing Record 36 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 9 | asfi
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 41 of Set 9 | whitecourt
# Processing Record 42 of Set 9 | velyka bahachka
# Processing Record 43 of Set 9 | eirunepe
# Processing Record 44 of Set 9 | luoyang
# Processing Record 45 of Set 9 | vestmanna
# Processing Record 46 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 9 | gamba
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | asino
# Processing Record 1 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 10 | moron
# Processing Record 3 of Set 10 | dingle
# Processing Record 4 of Set 10 | tevaitoa
# Processing Record 5 of Set 10 | leoben
# Processing Record 6 of Set 10 | jiazi
# Processing Record 7 of Set 10 | wilmington
# Processing Record 8 of Set 10 | jatoi
# City not found. Skipping...
# Processing Record 9 of Set 10 | ovalle
# Processing Record 10 of Set 10 | kilinochchi
# Processing Record 11 of Set 10 | klokkarvik
# City not found. Skipping...
# Processing Record 12 of Set 10 | touros
# Processing Record 13 of Set 10 | green river
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | pointe-noire
# Processing Record 16 of Set 10 | yazman
# Processing Record 17 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 10 | yar-sale
# Processing Record 19 of Set 10 | nurlat
# Processing Record 20 of Set 10 | svetlogorsk
# Processing Record 21 of Set 10 | thinadhoo
# Processing Record 22 of Set 10 | nouakchott
# Processing Record 23 of Set 10 | ambilobe
# Processing Record 24 of Set 10 | ruthin
# Processing Record 25 of Set 10 | stupino
# Processing Record 26 of Set 10 | naron
# Processing Record 27 of Set 10 | nelson bay
# Processing Record 28 of Set 10 | kasli
# Processing Record 29 of Set 10 | acarau
# Processing Record 30 of Set 10 | steti
# Processing Record 31 of Set 10 | neftcala
# Processing Record 32 of Set 10 | huarmey
# Processing Record 33 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 10 | asau
# Processing Record 35 of Set 10 | frederikshavn
# Processing Record 36 of Set 10 | port maria
# Processing Record 37 of Set 10 | ternate
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | palmer
# Processing Record 40 of Set 10 | shahr-e babak
# Processing Record 41 of Set 10 | tiznit
# Processing Record 42 of Set 10 | katsuura
# Processing Record 43 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 10 | girne
# Processing Record 45 of Set 10 | carbonia
# Processing Record 46 of Set 10 | fengcheng
# Processing Record 47 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 10 | killarney
# Processing Record 49 of Set 10 | adrar
# Processing Record 50 of Set 10 | saint-leu
# Processing Record 1 of Set 11 | biltine
# Processing Record 2 of Set 11 | mega
# Processing Record 3 of Set 11 | acari
# Processing Record 4 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 11 | batemans bay
# Processing Record 6 of Set 11 | ipixuna
# Processing Record 7 of Set 11 | rock springs
# Processing Record 8 of Set 11 | vinukonda
# Processing Record 9 of Set 11 | bubaque
# Processing Record 10 of Set 11 | zyryanka
# Processing Record 11 of Set 11 | san felipe
# Processing Record 12 of Set 11 | tarauaca
# Processing Record 13 of Set 11 | ferme-neuve
# Processing Record 14 of Set 11 | dudinka
# Processing Record 15 of Set 11 | santa maria
# Processing Record 16 of Set 11 | alta floresta
# Processing Record 17 of Set 11 | elk city
# Processing Record 18 of Set 11 | chipoka
# Processing Record 19 of Set 11 | odweyne
# Processing Record 20 of Set 11 | ilulissat
# Processing Record 21 of Set 11 | wanaka
# Processing Record 22 of Set 11 | villa guerrero
# Processing Record 23 of Set 11 | manjacaze
# Processing Record 24 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 11 | charters towers
# Processing Record 26 of Set 11 | bagdarin
# Processing Record 27 of Set 11 | sistranda
# Processing Record 28 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 11 | swellendam
# Processing Record 31 of Set 11 | henties bay
# Processing Record 32 of Set 11 | isangel
# Processing Record 33 of Set 11 | kjopsvik
# Processing Record 34 of Set 11 | centralia
# Processing Record 35 of Set 11 | hit
# Processing Record 36 of Set 11 | tangkak
# Processing Record 37 of Set 11 | isabela
# Processing Record 38 of Set 11 | pilar
# Processing Record 39 of Set 11 | olga
# Processing Record 40 of Set 11 | oktyabrskiy
# Processing Record 41 of Set 11 | vostok
# Processing Record 42 of Set 11 | chokwe
# Processing Record 43 of Set 11 | codajas
# Processing Record 44 of Set 11 | san francisco
# Processing Record 45 of Set 11 | songjianghe
# Processing Record 46 of Set 11 | yerofey pavlovich
# Processing Record 47 of Set 11 | gore
# Processing Record 48 of Set 11 | khani
# Processing Record 49 of Set 11 | weligama
# Processing Record 50 of Set 11 | seydi
# Processing Record 1 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 12 | gobabis
# Processing Record 3 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 4 of Set 12 | kutum
# Processing Record 5 of Set 12 | jiuquan
# Processing Record 6 of Set 12 | esperance
# Processing Record 7 of Set 12 | tuatapere
# Processing Record 8 of Set 12 | nabire
# Processing Record 9 of Set 12 | altamont
# Processing Record 10 of Set 12 | singapore
# Processing Record 11 of Set 12 | saint-pierre
# Processing Record 12 of Set 12 | dinan
# Processing Record 13 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 12 | xuddur
# Processing Record 15 of Set 12 | mindelo
# Processing Record 16 of Set 12 | deloraine
# Processing Record 17 of Set 12 | morgan city
# Processing Record 18 of Set 12 | davidson
# Processing Record 19 of Set 12 | liapades
# City not found. Skipping...
# Processing Record 20 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 12 | usinsk
# Processing Record 22 of Set 12 | krylovskaya
# Processing Record 23 of Set 12 | villa carlos paz
# Processing Record 24 of Set 12 | gavrilovka vtoraya
# Processing Record 25 of Set 12 | mokrousovo
# Processing Record 26 of Set 12 | gunjur
# Processing Record 27 of Set 12 | mitsamiouli
# Processing Record 28 of Set 12 | bone
# Processing Record 29 of Set 12 | tecoanapa
# Processing Record 30 of Set 12 | pangody
# Processing Record 31 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 12 | julio de castilhos
# Processing Record 33 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 12 | atar
# Processing Record 35 of Set 12 | vila franca do campo
# Processing Record 36 of Set 12 | kabare
# Processing Record 37 of Set 12 | kitimat
# Processing Record 38 of Set 12 | talara
# Processing Record 39 of Set 12 | altay
# Processing Record 40 of Set 12 | torbay
# Processing Record 41 of Set 12 | aswan
# Processing Record 42 of Set 12 | brigantine
# Processing Record 43 of Set 12 | montrose
# Processing Record 44 of Set 12 | broken hill
# Processing Record 45 of Set 12 | batagay-alyta
# Processing Record 46 of Set 12 | mecca
# Processing Record 47 of Set 12 | warrington
# Processing Record 48 of Set 12 | nenjiang
# Processing Record 49 of Set 12 | skibbereen
# Processing Record 50 of Set 12 | stornoway
# Processing Record 1 of Set 13 | olafsvik
# Processing Record 2 of Set 13 | irati
# Processing Record 3 of Set 13 | ixtapa
# Processing Record 4 of Set 13 | nuuk
# Processing Record 5 of Set 13 | vanimo
# Processing Record 6 of Set 13 | half moon bay
# Processing Record 7 of Set 13 | sao joao do piaui
# Processing Record 8 of Set 13 | suez
# Processing Record 9 of Set 13 | warmbad
# Processing Record 10 of Set 13 | meulaboh
# Processing Record 11 of Set 13 | hambantota
# Processing Record 12 of Set 13 | la asuncion
# Processing Record 13 of Set 13 | altagracia de orituco
# Processing Record 14 of Set 13 | puerto escondido
# Processing Record 15 of Set 13 | radford
# Processing Record 16 of Set 13 | tambacounda
# Processing Record 17 of Set 13 | maiduguri
# Processing Record 18 of Set 13 | ahipara
# Processing Record 19 of Set 13 | nouadhibou
# Processing Record 20 of Set 13 | mocuba
# Processing Record 21 of Set 13 | sibiti
# Processing Record 22 of Set 13 | yaan
# Processing Record 23 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 24 of Set 13 | camacupa
# Processing Record 25 of Set 13 | jumla
# Processing Record 26 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 27 of Set 13 | yarqa
# Processing Record 28 of Set 13 | coihaique
# Processing Record 29 of Set 13 | crotone
# Processing Record 30 of Set 13 | doha
# Processing Record 31 of Set 13 | solnechnyy
# Processing Record 32 of Set 13 | hervey bay
# Processing Record 33 of Set 13 | anupgarh
# Processing Record 34 of Set 13 | sibu
# Processing Record 35 of Set 13 | coahuayana
# Processing Record 36 of Set 13 | progreso
# Processing Record 37 of Set 13 | angoram
# Processing Record 38 of Set 13 | gorontalo
# Processing Record 39 of Set 13 | banswada
# Processing Record 40 of Set 13 | dakoro
# Processing Record 41 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 13 | marivan
# Processing Record 43 of Set 13 | peterhead
# Processing Record 44 of Set 13 | bondo
# Processing Record 45 of Set 13 | scarborough
# Processing Record 46 of Set 13 | ennis
# Processing Record 47 of Set 13 | christchurch
# Processing Record 48 of Set 13 | zabid
# Processing Record 49 of Set 13 | sokoni
# Processing Record 50 of Set 13 | port moresby
# Processing Record 1 of Set 14 | matamoros
# Processing Record 2 of Set 14 | miramar
# Processing Record 3 of Set 14 | bahadurganj
# Processing Record 4 of Set 14 | mayumba
# Processing Record 5 of Set 14 | kulachi
# Processing Record 6 of Set 14 | ingham
# Processing Record 7 of Set 14 | chenghai
# Processing Record 8 of Set 14 | mariental
# Processing Record 9 of Set 14 | ranikhet
# Processing Record 10 of Set 14 | khamanon
# Processing Record 11 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 14 | sogne
# Processing Record 13 of Set 14 | smithers
# Processing Record 14 of Set 14 | hella
# Processing Record 15 of Set 14 | iskateley
# Processing Record 16 of Set 14 | vakhrushev
# Processing Record 17 of Set 14 | lastoursville
# Processing Record 18 of Set 14 | aykhal
# Processing Record 19 of Set 14 | mizan teferi
# Processing Record 20 of Set 14 | junagarh
# Processing Record 21 of Set 14 | kysyl-syr
# Processing Record 22 of Set 14 | bulgan
# Processing Record 23 of Set 14 | dotnuva
# Processing Record 24 of Set 14 | kyzyl-suu
# Processing Record 25 of Set 14 | namatanai
# Processing Record 26 of Set 14 | ginir
# Processing Record 27 of Set 14 | bathsheba
# Processing Record 28 of Set 14 | muzhi
# Processing Record 29 of Set 14 | mayahi
# Processing Record 30 of Set 14 | lethem
# Processing Record 31 of Set 14 | tondano
# Processing Record 32 of Set 14 | biak
# Processing Record 33 of Set 14 | cruzeiro do sul
# Processing Record 34 of Set 14 | lukovetskiy
# Processing Record 35 of Set 14 | lavrentiya
# Processing Record 36 of Set 14 | pinega
# Processing Record 37 of Set 14 | iracoubo
# Processing Record 38 of Set 14 | gryazi
# Processing Record 39 of Set 14 | camalu
# Processing Record 40 of Set 14 | salamiyah
# Processing Record 41 of Set 14 | knysna
# Processing Record 42 of Set 14 | salvador
# Processing Record 43 of Set 14 | shostka
# Processing Record 44 of Set 14 | kracheh
# City not found. Skipping...
# Processing Record 45 of Set 14 | maldonado
# Processing Record 46 of Set 14 | athabasca
# Processing Record 47 of Set 14 | jalu
# Processing Record 48 of Set 14 | rock sound
# Processing Record 49 of Set 14 | kichmengskiy gorodok
# Processing Record 50 of Set 14 | rapid valley
# Processing Record 1 of Set 15 | egvekinot
# Processing Record 2 of Set 15 | lobito
# Processing Record 3 of Set 15 | lixourion
# Processing Record 4 of Set 15 | sola
# Processing Record 5 of Set 15 | harper
# Processing Record 6 of Set 15 | port macquarie
# Processing Record 7 of Set 15 | areia branca
# Processing Record 8 of Set 15 | frolovo
# Processing Record 9 of Set 15 | veraval
# Processing Record 10 of Set 15 | kieta
# Processing Record 11 of Set 15 | belyy yar
# Processing Record 12 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 15 | la ciotat
# Processing Record 14 of Set 15 | pipar
# Processing Record 15 of Set 15 | suraabad
# Processing Record 16 of Set 15 | capaci
# Processing Record 17 of Set 15 | yeppoon
# Processing Record 18 of Set 15 | nalgonda
# Processing Record 19 of Set 15 | minot
# Processing Record 20 of Set 15 | macenta
# Processing Record 21 of Set 15 | celestun
# Processing Record 22 of Set 15 | kharitonovo
# Processing Record 23 of Set 15 | polunochnoye
# Processing Record 24 of Set 15 | rawson
# Processing Record 25 of Set 15 | ranfurly
# Processing Record 26 of Set 15 | imeni poliny osipenko
# Processing Record 27 of Set 15 | haines junction
# Processing Record 28 of Set 15 | praia da vitoria
# Processing Record 29 of Set 15 | alcudia
# Processing Record 30 of Set 15 | guayape
# Processing Record 31 of Set 15 | gazanjyk
# Processing Record 32 of Set 15 | porto nacional
# Processing Record 33 of Set 15 | guiren
# Processing Record 34 of Set 15 | sioux lookout
# Processing Record 35 of Set 15 | zaton
# Processing Record 36 of Set 15 | siderno
# Processing Record 37 of Set 15 | chicama
# Processing Record 38 of Set 15 | nynashamn
# Processing Record 39 of Set 15 | hoquiam
# Processing Record 40 of Set 15 | qui nhon
# Processing Record 41 of Set 15 | ribas do rio pardo
# Processing Record 42 of Set 15 | beisfjord
# Processing Record 43 of Set 15 | salto
# Processing Record 44 of Set 15 | nosy varika
# Processing Record 45 of Set 15 | antofagasta
# Processing Record 46 of Set 15 | semirom
# Processing Record 47 of Set 15 | ghanzi
# Processing Record 48 of Set 15 | mafinga
# Processing Record 49 of Set 15 | kaeo
# Processing Record 50 of Set 15 | impfondo
# Processing Record 1 of Set 16 | kirakira
# Processing Record 2 of Set 16 | rorvik
# Processing Record 3 of Set 16 | sao jose da coroa grande
# Processing Record 4 of Set 16 | kempele
# Processing Record 5 of Set 16 | hami
# Processing Record 6 of Set 16 | longjiang
# Processing Record 7 of Set 16 | rouvroy
# Processing Record 8 of Set 16 | challans
# Processing Record 9 of Set 16 | santa eulalia del rio
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Victor Harbor -35.5667  138.6167     59.94        93           0
# 1      Las Varas  21.1667 -105.1667     62.08        68          27
# 2         Ranong   9.9658   98.6348     80.04        82          98
# 3      Mahebourg -20.4081   57.7000     79.25        83          40
# 4          Vardo  70.3705   31.1107     33.78        93          75
# 5         Castro -24.7911  -50.0119     68.59        81          97
# 6         Atuona  -9.8000 -139.0333     78.55        78          14
# 7      Jamestown  42.0970  -79.2353     48.72        79         100
# 8     Butaritari   3.0707  172.7902     80.85        81          99
# 9     Bredasdorp -34.5322   20.0403     64.65        49          79
#
#    Wind Speed Country                 Date
# 0        4.63      AU  2022-04-07 14:25:59
# 1        2.17      MX  2022-04-07 14:25:59
# 2        2.91      TH  2022-04-07 14:25:59
# 3        9.22      MU  2022-04-07 14:26:00
# 4       20.71      NO  2022-04-07 14:26:00
# 5        4.85      BR  2022-04-07 14:25:22
# 6       16.26      PF  2022-04-07 14:26:00
# 7        6.91      US  2022-04-07 14:23:17
# 8       16.26      KI  2022-04-07 14:26:01
# 9       10.80      ZA  2022-04-07 14:25:57

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
